# %%
import trustpilotreviews

# %%
# Initiate it. Language will be required
t = trustpilotreviews.GetReviews()

# Pass in web-page address as it appears in trustpilot.com
g_usa= t.get_id('www.glassesusa.com')

# Check if everything is ok
if g_usa.ok:
    print(g_usa.business_id)

# Gather data from that id
data = t.get_reviews()
# Out:
# Select language:
# 	dk for danish
# 	no for norwegian
# 	se for swedish
# 	fi for finish
# 	en for english
# >  en
#    English selected
# Waiting businesses Ids ...
# 4a89c04f00006400050497f3
# GlassesUSA 7020 reviews: 100%|██████████ [time left: 00:00 ]

# %%
import pandas as pd

# %%
pd.DataFrame(t.dictData).to_csv("G_USA_TP_Reviews1.csv")

# %%
import feedgen

# %%
feedgen?
# Out:
# Type:        module
# String form: <module 'feedgen' from '/home/animesh/anaconda3/lib/python3.7/site-packages/feedgen/__init__.py'>
# File:        ~/anaconda3/lib/python3.7/site-packages/feedgen/__init__.py
# Docstring:
# ...
# feedgen
# ...
#
# This module can be used to generate web feeds in both ATOM and RSS format.
# It has support for extensions. Included is for example an extension to
# produce Podcasts.
#
# :copyright: 2013 by Lars Kiesow
# :license: FreeBSD and LGPL, see license.* for more details.
#
#
# -------------
# Create a Feed
# -------------
#
# To create a feed simply instantiate the FeedGenerator class and insert some
# data::
#
#     >>> from feedgen.feed import FeedGenerator
#     >>> fg = FeedGenerator()
#     >>> fg.id('http://lernfunk.de/media/654321')
#     >>> fg.title('Some Testfeed')
#     >>> fg.author( {'name':'John Doe','email':'john@example.de'} )
#     >>> fg.link( href='http://example.com', rel='alternate' )
#     >>> fg.logo('http://ex.com/logo.jpg')
# ...

# %%
df = pd.read_csv('G_USA_TP_Reviews.csv')

# %%
df
# Out:
#       Unnamed: 0         reviewerName  \
# 0              0        William Mckee
# 1              1  Satisfied Customer
# 2              2      Cynthia Edwards
# 3              3           Renee Dunn
# 4              4       cody klibansky
# 5              5             Dessy GT
# 6              6                   FB
# 7              7        Raymond Ellis
# 8              8     Keith Washington
# 9              9       Alyson Recinos
# 10            10             Todd Lam
# 11            11        Ivanna Chavez
# 12            12          yisrael raz
# 13            13         Lynette Voss
# 14            14      Edgar Gutierrez
# 15            15        BRYANT MANLEY
# 16            16           Kevin West
# 17            17          James Opila
# 18            18                Nixon
# 19            19         Jesus Sotelo
# 20            20      Judith Jeffords
# 21            21    Danielle Tanksley
# 22            22             Robert H
# ...

# %%
t = trustpilotreviews.GetReviews()
# Out:
# Select language:
# 	dk for danish
# 	no for norwegian
# 	se for swedish
# 	fi for finish
# 	en for english
# >  sfd
# Invalid selection. Trying again ...
# Select language:
# 	dk for danish
# 	no for norwegian
# 	se for swedish
# 	fi for finish
# 	en for english
# >  en
#    English selected
# Waiting businesses Ids ...
